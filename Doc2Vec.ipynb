# %%
import pandas as pd
import csv

# %%
auth  = pd.read_csv('Title',sep='#')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-8-dff083e01346> in <module>()
# ----> 1 auth  = pd.read_csv('Title',sep='#')
#
# ...

# %%
auth
# Out:
#                                             sigID || title
# 0        1 || A new relictual and highly troglomorphic ...
# 1        2 || A new relictual and highly troglomorphic ...
# 2        3 || A new relictual and highly troglomorphic ...
# 3        4 || Phase Diagram and Electrical Conductivity...
# 4        5 || Phase Diagram and Electrical Conductivity...
# 5        6 || Phase Diagram and Electrical Conductivity...
# 6        7 || Phase Diagram and Electrical Conductivity...
# 7        8 || MIL-53(Fe): a good example to illustrate ...
# 8        9 || MIL-53(Fe): a good example to illustrate ...
# 9        10 || MIL-53(Fe): a good example to illustrate...
# 10       11 || Powder diffraction methods for studies o...
# 11       12 || Powder diffraction methods for studies o...
# 12       13 || Powder diffraction methods for studies o...
# 13       14 || Powder diffraction methods for studies o...
# 14       15 || Time-dependent analysis of K2PtBr6 bindi...
# ...
